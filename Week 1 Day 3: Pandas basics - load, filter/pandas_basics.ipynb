# %% [markdown]
# > ## Day 3: Matplotlib - Visualizations
# > ### Author: Yahya Ahmad

# %%
import pandas as pd

df = pd.read_csv(r'D:\Courses\Data_Scientist\Week1_Python_SQL\d2\Amazon Sale Report.csv')
# Out:
# C:\Users\ya028\AppData\Local\Temp\ipykernel_19084\1022626056.py:3: DtypeWarning: Columns (0: Unnamed: 22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'D:\Courses\Data_Scientist\Week1_Python_SQL\d2\Amazon Sale Report.csv')

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category Size        ASIN Courier Status  Qty currency  Amount  \
# ...

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='str')

# %%
df.loc[0:5, 'Order ID']
# Out:
# 0    405-8078784-5731545
# 1    171-9198151-1101146
# 2    404-0687676-7273146
# 3    403-9615377-8133951
# 4    407-1069790-7240320
# 5    404-1490984-4578765
# Name: Order ID, dtype: str

# %% [markdown]
# #### for practice

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

dff = pd.DataFrame(people)
dff
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
dff.shape
# Out:
# (3, 3)

# %%
dff[['first', 'email']]
# Out:
#    first                    email
# 0  Corey  CoreyMSchafer@gmail.com
# 1   Jane        JaneDoe@email.com
# 2   John        JohnDoe@email.com

# %%
dff.iloc[[0,1], 0]
# Out:
# 0    Corey
# 1     Jane
# Name: first, dtype: str

# %%
# indexing
dff.set_index('last', inplace=True)

# %%
dff
# Out:
#          first                    email
# last
# Schafer  Corey  CoreyMSchafer@gmail.com
# Doe       Jane        JaneDoe@email.com
# Doe       John        JohnDoe@email.com

# %%
dff.sort_index()
# Out:
#          first                    email
# last
# Doe       Jane        JaneDoe@email.com
# Doe       John        JohnDoe@email.com
# Schafer  Corey  CoreyMSchafer@gmail.com

# %% [markdown]
# ### back to the orignial dataset

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category Size        ASIN Courier Status  Qty currency  Amount  \
# ...

# %%
df['Fulfilment'].value_counts()
# Out:
# Fulfilment
# Amazon      89698
# Merchant    39277
# Name: count, dtype: int64

# %%
# first five
df.loc[0:4,'Fulfilment']
# Out:
# 0    Merchant
# 1    Merchant
# 2      Amazon
# 3    Merchant
# 4      Amazon
# Name: Fulfilment, dtype: str

# %%
# indexing
df.set_index('Order ID', inplace=True)

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category Size        ASIN Courier Status  Qty currency  Amount  \
# ...

# %%
# filtering
Merchand = (df['Fulfilment'] == 'Merchant') & (df['Status'] == 'Shipped - Delivered to Buyer')

# %%
df.loc[Merchand, ['Category','Qty', 'Size']]
# Out:
#              Category  Qty Size
# 1               kurta    1  3XL
# 7               kurta    1    S
# 12              kurta    1   XS
# 14                Set    1    L
# 15              kurta    1  6XL
# ...               ...  ...  ...
# 128872   Ethnic Dress    1    S
# 128873            Set    1    S
# 128874            Set    1    S
# 128887            Top    1    M
# 128891  Western Dress    1    M
#
# [28769 rows x 3 columns]

# %%
df.to_csv(r'D:\Courses\Data_Scientist\Week1_Python_SQL\d2\Amazon Sale Report (Merchant).csv', index=False)
